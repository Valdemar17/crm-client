# %% [markdown]
# # Plan for Dictamen Juridico List View
#
# 1.  **State Management**:
#     *   Add `viewMode` state (`'list'` vs `'form'`). Default to `'list'`.
#     *   Add `mockRequests` data matching the image structure.
#
# 2.  **List View UI**:
#     *   Header: Title "Dictámenes Jurídicos", "Nueva Solicitud" button.
#     *   Table:
#         *   Columns: Folio, Cliente, Producto, Monto, Estatus, Etapa, Acciones.
#         *   Style: Clean, white background, hover effects on rows.
#     *   Row Click: Sets `viewMode = 'form'`.
#
# 3.  **Navigation Logic**:
#     *   In `'list'` mode: "Volver" calls `props.onBack` (returns to Main Dashboard).
#     *   In `'form'` mode: "Volver" sets `viewMode = 'list'`.
#
# 4.  **Implementation Details**:
#     *   Insert the list rendering logic *before* the current return.
#     *   Wrap current return in `if (viewMode === 'form')`.
#     *   Ensure CSS classes match the application style (Tailwind).
#
# ```jsx
# // Mock Data
# const mockRequests = [
#   { folio: '#CR-2023-001', cliente: 'Transportes del Norte S.A.', producto: 'Arrendamiento', monto: '$1,500,000', estatus: 'En Proceso', etapa: 'Dictamen Jurídico', statusColor: 'bg-yellow-100 text-yellow-800' },
#   { folio: '#CR-2023-002', cliente: 'Juan Pérez Martínez', producto: 'Crédito Simple', monto: '$350,000', estatus: 'Análisis', etapa: 'Recopilación de Documentos', statusColor: 'bg-blue-100 text-blue-800' },
#   // ... more
# ];
# ```
